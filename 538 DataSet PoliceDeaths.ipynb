# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/HP/Desktop/fivethirtyeight/data/police-deaths/all_data police death.csv',encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#                        person  \
# 0     Constable Darius Quimby
# 1  Sheriff Cornelius Hogeboom
# 2  Deputy Sheriff Isaac Smith
# 3      Marshal Robert Forsyth
# 4      Sheriff Robert Maxwell
#
#                                                 dept  \
# 0               Albany County Constable's Office, NY
# 1               Columbia County Sheriff's Office, NY
# 2        Westchester County Sheriff's Department, NY
# 3  United States Department of Justice - United S...
# 4             Greenville County Sheriff's Office, SC
#
#                                eow                    cause
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
# 2      EOW: Thursday, May 17, 1792  Cause of Death: Gunfire
# 3  EOW: Saturday, January 11, 1794  Cause of Death: Gunfire
# 4   EOW: Sunday, November 12, 1797  Cause of Death: Gunfire

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire

# %%
data['NAME'] = data['person']

# %%
data['DESIGNATION'] = data['person'].apply(lambda x:x.split(' ')[0])

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION
# 0     Constable Darius Quimby   Constable
# 1  Sheriff Cornelius Hogeboom     Sheriff

# %%
data['DEPARTMENT'] = data['dept'].apply(lambda x:x.split(',')[0])

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office

# %%
data['STATE'] = data['dept'].apply(lambda x:x.split(',')[-1])

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE
# 0    NY
# 1    NY

# %%
data['YEAR'] = data['eow'].apply(lambda x:x.split(',')[-1])

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR
# 0    NY   1791
# 1    NY   1791

# %%
data['month'] = data['eow'].apply(lambda x:x.split(',')[1])

# %%
data['MONTH'] = data['month'].apply(lambda x:x.split(' ')[1])

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR        month    MONTH
# 0    NY   1791    January 3  January
# 1    NY   1791   October 22  October

# %%
data['DATE'] = data['month'].apply(lambda x:x.split(' ')[2])

# %%
data.head(2)
# Out:
#                        person                                  dept  \
# 0     Constable Darius Quimby  Albany County Constable's Office, NY
# 1  Sheriff Cornelius Hogeboom  Columbia County Sheriff's Office, NY
#
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR        month    MONTH DATE
# 0    NY   1791    January 3  January    3
# 1    NY   1791   October 22  October   22

# %%
del data['month']

# %%
del data['person']

# %%
del data['dept']

# %%
data.head(2)
# Out:
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR    MONTH DATE
# 0    NY   1791  January    3
# 1    NY   1791  October   22

# %%
data['day'] = data['eow'].apply(lambda x:x.split(',')[0])

# %%
data.head(2)
# Out:
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR    MONTH DATE            day
# 0    NY   1791  January    3    EOW: Monday
# 1    NY   1791  October   22  EOW: Saturday

# %%
data['DAY'] = data['day'].apply(lambda x:x.split(':')[1])

# %%
data.head(2)
# Out:
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR    MONTH DATE            day        DAY
# 0    NY   1791  January    3    EOW: Monday     Monday
# 1    NY   1791  October   22  EOW: Saturday   Saturday

# %%
del data['day']

# %%
data.head(2)
# Out:
#                                eow                    cause  \
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
#
#                          NAME DESIGNATION                        DEPARTMENT  \
# 0     Constable Darius Quimby   Constable  Albany County Constable's Office
# 1  Sheriff Cornelius Hogeboom     Sheriff  Columbia County Sheriff's Office
#
#   STATE   YEAR    MONTH DATE        DAY
# 0    NY   1791  January    3     Monday
# 1    NY   1791  October   22   Saturday

# %%
del data['eow']

# %%
data.head(2)
# Out:
#                      cause                        NAME DESIGNATION  \
# 0  Cause of Death: Gunfire     Constable Darius Quimby   Constable
# 1  Cause of Death: Gunfire  Sheriff Cornelius Hogeboom     Sheriff
#
#                          DEPARTMENT STATE   YEAR    MONTH DATE        DAY
# 0  Albany County Constable's Office    NY   1791  January    3     Monday
# 1  Columbia County Sheriff's Office    NY   1791  October   22   Saturday

# %%
data['CAUSE'] = data['cause'].apply(lambda x:x.split(':')[-1])

# %%
data.head()
# Out:
#                      cause                        NAME DESIGNATION  \
# 0  Cause of Death: Gunfire     Constable Darius Quimby   Constable
# 1  Cause of Death: Gunfire  Sheriff Cornelius Hogeboom     Sheriff
# 2  Cause of Death: Gunfire  Deputy Sheriff Isaac Smith      Deputy
# 3  Cause of Death: Gunfire      Marshal Robert Forsyth     Marshal
# 4  Cause of Death: Gunfire      Sheriff Robert Maxwell     Sheriff
#
#                                           DEPARTMENT STATE   YEAR     MONTH  \
# 0                   Albany County Constable's Office    NY   1791   January
# 1                   Columbia County Sheriff's Office    NY   1791   October
# 2            Westchester County Sheriff's Department    NY   1792       May
# 3  United States Department of Justice - United S...    US   1794   January
# 4                 Greenville County Sheriff's Office    SC   1797  November
#
#   DATE        DAY     CAUSE
# 0    3     Monday   Gunfire
# 1   22   Saturday   Gunfire
# ...

# %%
del data['cause']

# %%
data.head(25)
# Out:
#                                    NAME DESIGNATION  \
# 0               Constable Darius Quimby   Constable
# 1            Sheriff Cornelius Hogeboom     Sheriff
# 2            Deputy Sheriff Isaac Smith      Deputy
# 3                Marshal Robert Forsyth     Marshal
# 4                Sheriff Robert Maxwell     Sheriff
# 5       High Sheriff John Caldwell Cook        High
# 6          Watchman Christian Luswanger    Watchman
# 7          Deputy Sheriff John A. Gooch      Deputy
# 8        Deputy Sheriff Ebenezer Parker      Deputy
# 9         Night Watchman George Workner       Night
# 10                    Boatman Asa Marsh     Boatman
# 11                  Boatman Ellis Drake     Boatman
# 12   Custom House Officer Daniel Miller      Custom
# 13  Deputy Sheriff John Tileston Downes      Deputy
# 14         Customs Inspector John Stout     Customs
# 15             Sheriff John Coor Pender     Sheriff
# 16                 Sheriff Caleb Hewitt     Sheriff
# ...

# %%
data.isnull().sum()
# Out:
# NAME           0
# DESIGNATION    0
# DEPARTMENT     0
# STATE          0
# YEAR           0
# MONTH          0
# DATE           0
# DAY            0
# CAUSE          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22800 entries, 0 to 22799
# Data columns (total 9 columns):
# NAME           22800 non-null object
# DESIGNATION    22800 non-null object
# DEPARTMENT     22800 non-null object
# STATE          22800 non-null object
# YEAR           22800 non-null object
# MONTH          22800 non-null object
# DATE           22800 non-null object
# DAY            22800 non-null object
# CAUSE          22800 non-null object
# dtypes: object(9)
# memory usage: 1.6+ MB

# %%
data['DATE'] = data['DATE'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22800 entries, 0 to 22799
# Data columns (total 9 columns):
# NAME           22800 non-null object
# DESIGNATION    22800 non-null object
# DEPARTMENT     22800 non-null object
# STATE          22800 non-null object
# YEAR           22800 non-null object
# MONTH          22800 non-null object
# DATE           22800 non-null int64
# DAY            22800 non-null object
# CAUSE          22800 non-null object
# dtypes: int64(1), object(8)
# memory usage: 1.6+ MB

# %%
data.to_csv('fairco')

# %%
data['YEAR'].value_counts()
# Out:
#  1930    323
#  1927    305
#  1932    301
#  1931    296
#  1924    289
#  1921    287
#  1929    286
#  1974    281
#  1973    277
#  1925    276
#  1928    275
#  1922    264
#  1926    258
#  1934    256
#  1971    251
#  1923    251
#  1975    247
#  2001    247
#  1933    244
#  1919    243
#  1935    238
#  1972    237
#  1970    231
#  1920    224
#  1979    223
#  1978    217
#  1980    213
#  2007    213
#  1936    210
#  1937    205
#         ...
#  1844      4
#  1849      4
#  1808      4
#  1841      4
#  1843      3
#  1847      3
#  1791      2
#  1834      2
#  1825      2
#  1840      2
#  1823      2
#  1816      2
#  1811      1
#  1794      1
#  1824      1
#  1827      1
#  1806      1
#  1810      1
#  1814      1
#  1848      1
#  1832      1
#  1842      1
#  1833      1
#  1807      1
#  1828      1
#  1830      1
#  1797      1
#  1804      1
#  1818      1
#  1792      1
# Name: YEAR, Length: 202, dtype: int64
